# %%
"""
This is a test file for looking at sample shape statistics data
"""

# This is used to set directory to correct project
# import os
# print(os.getcwd())
# os.chdir(r'C:\Users\solan\OneDrive\Desktop\IntrotoPython\FinalProj\cropfield-polygonization') # Change path to personal path to project

# Note: Install pandas, geopandas

import geopandas as gpd
import pandas as pd

# %%
zambia_shp = gpd.read_parquet(r'data\zambia_2023_attributed.parquet')

# %%
# General Info
display(zambia_shp.columns.tolist())

display(zambia_shp.info())

zambia_shp.head(10)
# Out:
# ['area_m2',
#  'area_ha',
#  'perimeter_m',
#  'compactness',
#  'shape_index',
#  'interior_edge',
#  'fractal_dim',
#  'tile_id',
#  'polygon_index',
#  'polygon_id',
#  'geometry']
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8327646 entries, 0 to 8327645
# Data columns (total 11 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   area_m2        float64
#  1   area_ha        float64
#  2   perimeter_m    float64
#  3   compactness    float64
#  4   shape_index    float64
#  5   interior_edge  float64
#  6   fractal_dim    float64
#  7   tile_id        float64
#  8   polygon_index  float64
#  9   polygon_id     float64
#  10  geometry       geometry
# dtypes: float64(10), geometry(1)
# memory usage: 698.9 MB
# None
#          area_m2    area_ha  perimeter_m  compactness  shape_index  \
# 0  151068.586899  15.106859  4141.286922     0.110691     3.005684
# 1   22061.759097   2.206176   608.624031     0.748431     1.155910
# 2    1307.204778   0.130720   154.951184     0.684169     1.208977
# 3    3958.970804   0.395897   299.582238     0.554319     1.343136
# 4     683.484230   0.068348    97.299749     0.907225     1.049887
# 5    5086.916144   0.508692   268.154096     0.888987     1.060601
# 6     530.356992   0.053036    89.968177     0.823380     1.102046
# 7    4612.613794   0.461261   260.301541     0.855467     1.081181
# 8   24571.995957   2.457200  1128.690568     0.242382     2.031186
# 9     392.167048   0.039217    90.582792     0.600606     1.290343
#
#    interior_edge  fractal_dim   tile_id  polygon_index    polygon_id  \
# 0       0.027413     1.396800  895920.0            0.0  8.959200e+11
# 1       0.027587     1.282035  895920.0            1.0  8.959200e+11
# 2       0.118536     1.405618  895920.0            2.0  8.959200e+11
# 3       0.075672     1.376767  895920.0            3.0  8.959200e+11
# 4       0.142358     1.402682  895920.0            4.0  8.959200e+11
# 5       0.052714     1.310354  895920.0            5.0  8.959200e+11
# 6       0.169637     1.434421  895920.0            6.0  8.959200e+11
# 7       0.056433     1.318511  895920.0            7.0  8.959200e+11
# 8       0.045934     1.390555  895920.0            8.0  8.959200e+11
# 9       0.230980     1.509210  895920.0            9.0  8.959200e+11
#
#                                             geometry
# 0  POLYGON ((23.41239 -14.25764, 23.41244 -14.257...
# 1  POLYGON ((23.41479 -14.25959, 23.41474 -14.259...
# 2  POLYGON ((23.41364 -14.25734, 23.41386 -14.257...
# 3  POLYGON ((23.41341 -14.25666, 23.41351 -14.256...
# 4  POLYGON ((23.41316 -14.25651, 23.41311 -14.256...
# 5  POLYGON ((23.41462 -14.25601, 23.41484 -14.256...
# 6  POLYGON ((23.41144 -14.25514, 23.41144 -14.254...
# 7  POLYGON ((23.41241 -14.25488, 23.41239 -14.255...
# 8  POLYGON ((23.41609 -14.25471, 23.41607 -14.254...
# 9  POLYGON ((23.41169 -14.25393, 23.41181 -14.253...

# %%
# min/max compactness, shape_index, interior_edge, fractal_dim

def min1(col: pd.Series): 
    return col.min()

display(min1(zambia_shp["compactness"]))
display(min1(zambia_shp["shape_index"]))
display(min1(zambia_shp["interior_edge"]))
display(min1(zambia_shp["fractal_dim"]))

def max1(col: pd.Series): 
    return col.min()

display(max1(zambia_shp["compactness"]))
display(max1(zambia_shp["shape_index"]))
display(max1(zambia_shp["interior_edge"]))
display(max1(zambia_shp["fractal_dim"]))
# Out:
# 0.001112033152492294
# 1.0038838814155713
# 0.00034622530182215925
# 1.1580728451772884
# 0.001112033152492294
# 1.0038838814155713
# 0.00034622530182215925
# 1.1580728451772884

# %%
# range of compactness, shape_index, interior_edge, fractal_dim

def range1(col: pd.Series): 
    return col.max() - col.min()

display(range1(zambia_shp["compactness"]))
display(range1(zambia_shp["shape_index"]))
display(range1(zambia_shp["interior_edge"]))
range1(zambia_shp["fractal_dim"])
# Out:
# 0.9911652244071747
# 28.98367630167081
# 3.8592269706816396
# 1.705777313020966

# %%
print(zambia_shp.crs)
# Out:
# {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}, {"name": "World Geodetic System 1984 (G2296)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}

# %%
# Plot based on shapeindex
zambia_shp.head(100).plot(column="shape_index", cmap="viridis", legend=True)
# Out:
# <Axes: >
